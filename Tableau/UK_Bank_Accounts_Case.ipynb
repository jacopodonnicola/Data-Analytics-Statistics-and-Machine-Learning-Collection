# %%
from IPython.display import display, Image

image_path = 'Dashboard.png' 
display(Image(filename=image_path))

# %% [markdown]
# Link to the complete dashboard : https://public.tableau.com/views/UKBankAccountsCase/Dashboard1?:language=en-US&:sid=&:display_count=n&:origin=viz_share_link
